# %% [markdown]
# Forschungsfrage: Wie haben sich Häufigkeit, Intensität (Spitzen- und Durchschnittstemperatur) und Dauer von Hitzewellen in deutschen Großstädten (≥150.000 EW) zwischen 1980 und heute verändert?
#
# Datenbasis: 57 deutsche Städte ≥150.000 Einwohner (Wikidata), Tages-Maximaltemperaturen aus dem Open-Meteo-Archiv (ERA5-Reanalyse) 1961–2025. Hitzewellen nach DWD-Definition: ≥3 aufeinanderfolgende Tage über dem lokalen 98.-Perzentil (Referenzperiode 1961–1990) und über 28 °C.

# %% [markdown]
# Zelle 1 — Städte laden
#
# Diese Zelle fragt über eine SPARQL-Anfrage bei Wikidata alle deutschen Städte mit mehr als 150.000 Einwohnern ab, inklusive ihrer Koordinaten. Das Ergebnis landet als sortiertes DataFrame in cities_df. Die Basis für alle folgenden Schritte.

# %%
# Deutsche Großstädte >150.000 Einwohner mit Koordinaten (Wikidata-SPARQL-API)
import requests
import pandas as pd
import numpy as np
import time

def get_german_cities(min_population=150000):
    # SPARQL-Query: Stadt in Deutschland, mit Einwohnerzahl und Koordinaten
    query = f"""
    SELECT DISTINCT ?cityLabel ?population ?coord WHERE {{
      # ?city wdt:P31/wdt:P279* wd:Q515;      # ist eine Stadt
            wdt:P17 wd:Q183;                # liegt in Deutschland
            wdt:P1082 ?population;          # hat Einwohnerzahl
            wdt:P625 ?coord.                # hat Koordinaten
      FILTER(?population >= {min_population})
      SERVICE wikibase:label {{ bd:serviceParam wikibase:language "de,en". }}
    }}
    ORDER BY DESC(?population)
    """
    url = "https://query.wikidata.org/sparql"
    headers = {"Accept": "application/sparql-results+json", "User-Agent": "student-project/1.0"}
    r = requests.get(url, params={"query": query}, headers=headers)
    r.raise_for_status()  # Fehler werfen, falls Anfrage fehlschlägt

    rows = r.json()["results"]["bindings"]
    cities = []
    for row in rows:
        name = row["cityLabel"]["value"]
        pop = int(row["population"]["value"])
        # Koordinaten kommen als Text "Point(lon lat)" -> aufsplitten
        lon, lat = row["coord"]["value"].replace("Point(", "").replace(")", "").split(" ")
        cities.append({"city": name, "population": pop, "lat": float(lat), "lon": float(lon)})

    df = pd.DataFrame(cities).drop_duplicates(subset="city")  # Duplikate entfernen
    return df.sort_values("population", ascending=False).reset_index(drop=True)

cities_df = get_german_cities(min_population=150000)
print(cities_df)
print(f"Anzahl Städte: {len(cities_df)}")
# Out:
#                        city  population        lat        lon
# 0                    Berlin     3782202  52.516667  13.383333
# 1                   Hamburg     1910160  53.550000  10.000000
# 2                   München     1510378  48.137500  11.575000
# 3                      Köln     1024621  50.942222   6.957778
# 4         Frankfurt am Main      775790  50.110556   8.682222
# 5   Freie Hansestadt Bremen      693204  53.133333   8.733333
# 6                 Stuttgart      633484  48.777500   9.180000
# 7                Düsseldorf      631217  51.225556   6.776667
# 8                   Leipzig      611850  51.340632  12.374733
# 9                  Dortmund      595471  51.513889   7.465278
# 10                    Essen      586608  51.450833   7.013056
# 11                   Bremen      577026  53.075833   8.807222
# 12                  Dresden      564904  51.049329  13.738144
# 13                 Hannover      548186  52.374444   9.738611
# 14                 Nürnberg      529508  49.453889  11.077500
# 15                 Duisburg      500810  51.432222   6.761111
# 16                   Bochum      366385  51.483333   7.216667
# 17                Wuppertal      358938  51.266667   7.183333
# 18                Bielefeld      338410  52.016667   8.533333
# 19                     Bonn      335789  50.735278   7.102222
# 20                 Mannheim      316877  49.487778   8.466111
# 21                Karlsruhe      309964  49.016667   8.400000
# 22                  Münster      306368  51.962500   7.625556
# 23                 Augsburg      303150  48.368889  10.897778
# 24                Wiesbaden      285522  50.082500   8.240000
# 25          Mönchengladbach      268943  51.200000   6.433333
# 26            Gelsenkirchen      265885  51.510278   7.094167
# 27                   Aachen      252769  50.776207   6.083788
# 28                     Kiel      252668  54.323333  10.139444
# 29             Braunschweig      252066  52.269167  10.521111
# 30                 Chemnitz      245618  50.832353  12.918914
# 31            Halle (Saale)      242172  51.482778  11.969722
# 32                Magdeburg      240114  52.131589  11.639961
# 33     Freiburg im Breisgau      237244  47.995000   7.850000
# 34                  Krefeld      228550  51.333333   6.566667
# 35                    Mainz      222889  49.999444   8.273611
# 36                   Lübeck      219044  53.869722  10.686389
# 37                   Erfurt      215199  50.978056  11.028889
# 38               Oberhausen      211099  51.469900   6.851400
# 39                  Rostock      210795  54.083333  12.133333
# 40                   Kassel      204687  51.315778   9.497917
# 41                    Hagen      190384  51.359444   7.475000
# 42                  Potsdam      187119  52.400931  13.059140
# 43              Saarbrücken      183509  49.233333   7.000000
# 44                     Hamm      180761  51.681389   7.819167
# 45    Ludwigshafen am Rhein      176110  49.481111   8.435278
# 46                Oldenburg      174629  53.143889   8.213889
# 47      Mülheim an der Ruhr      173255  51.427500   6.882500
# 48                Osnabrück      166960  52.278889   8.043056
# 49               Leverkusen      166414  51.033333   6.983333
# 50                Darmstadt      164792  49.866667   8.650000
# 51               Heidelberg      162960  49.409358   8.694724
# 52                 Solingen      161545  51.171944   7.084722
# 53                    Herne      157896  51.542580   7.218970
# 54                Paderborn      155749  51.716667   8.766667
# 55                    Neuss      155163  51.200278   6.693889
# 56               Regensburg      151517  49.016667  12.083333
# Anzahl Städte: 57

# %% [markdown]
# Statt einer normalen requests.Session bauen wir eine requests_cache.CachedSession (persistenter SQLite-Cache, nie ablaufend, nur echte 200er-Antworten werden gespeichert) und montieren darauf unsere eigene Retry-Strategie inklusive 429. Diese Session wird an den openmeteo_requests-Client übergeben, der die eigentliche Kommunikation (inkl. FlatBuffers-Parsing) übernimmt.

# %%
# Open-Meteo-Client: FlatBuffers-Client + persistenter Cache + eigene Retry-Logik (inkl. 429)
import openmeteo_requests
import requests_cache
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

def make_client():
    cache_session = requests_cache.CachedSession(
        "openmeteo_cache",      # Datei: openmeteo_cache.sqlite
        expire_after=-1,         # nie ablaufen -- Klimadaten ändern sich nicht rückwirkend
        allowable_codes=[200],   # 429/Fehler werden NIE gecacht
    )
    retry = Retry(
        total=6, backoff_factor=3,                       # 3s, 6s, 12s, 24s, 48s, 96s
        status_forcelist=[429, 500, 502, 503, 504],       # 429 explizit dabei
        allowed_methods=["GET"],
    )
    cache_session.mount("https://", HTTPAdapter(max_retries=retry))
    cache_session.headers.update({"User-Agent": "student-project/1.0"})
    return openmeteo_requests.Client(session=cache_session)

CLIENT = make_client()

# %% [markdown]
# fetch_tmax_batch nutzt jetzt CLIENT.weather_api(...) statt session.get(...) und baut die Koordinatenlisten direkt als Python-Listen (keine Komma-Strings mehr nötig). Die restlichen drei Funktionen (Schwellenwerte, Hitzewellen-Erkennung, Verknüpfung) bleiben inhaltlich exakt wie zuvor.

# %%
# Funktionen: Wetterdaten laden (openmeteo_requests) + Hitzewellen erkennen
import time

ARCHIVE_URL = "https://archive-api.open-meteo.com/v1/archive"

def fetch_tmax_batch(client, coords, start_date, end_date, batch_size=15, pause=5):
    """Holt Tages-Maximaltemperaturen für mehrere Städte gleichzeitig."""
    dfs = []
    n_batches = -(-len(coords) // batch_size)  # aufrunden

    for b in range(n_batches):
        i = b * batch_size
        chunk = coords[i:i + batch_size]  # ein Batch von Städten

        params = {
            "latitude": [lat for lat, lon in chunk],
            "longitude": [lon for lat, lon in chunk],
            "start_date": start_date, "end_date": end_date,
            "daily": ["temperature_2m_max"],
            "timezone": "Europe/Berlin",
        }
        try:
            responses = client.weather_api(ARCHIVE_URL, params=params)  # immer eine Liste
        except Exception as e:
            raise RuntimeError(f"API-Fehler bei Batch {b+1}/{n_batches}: {e}") from e

        for response in responses:
            daily = response.Daily()
            tmax = daily.Variables(0).ValuesAsNumpy()  # 0 = einzige angeforderte Variable
            dates = pd.date_range(
                start=pd.to_datetime(daily.Time(), unit="s", utc=True),
                end=pd.to_datetime(daily.TimeEnd(), unit="s", utc=True),
                freq=pd.Timedelta(seconds=daily.Interval()),
                inclusive="left",
            ).tz_localize(None)  # Zeitzone abstreifen, reine Kalendertage reichen
            dfs.append(pd.DataFrame({"date": dates, "tmax": tmax}))

        aus_cache = getattr(responses[0], "from_cache", False) if hasattr(responses[0], "from_cache") else False
        print(f"  Batch {b+1}/{n_batches} ok ({len(chunk)} Städte)")
        time.sleep(pause)

    return dfs

def fetch_tmax_range(client, coords, start_date, end_date, batch_size=15, year_chunk=5, pause=5):
    """Holt Tmax über einen langen Zeitraum, aufgeteilt in Städte-Batches
    UND Jahres-Blöcke -- jede einzelne Anfrage bleibt klein, Fortschritt
    ist granular im HTTP-Cache gesichert."""
    start_year, end_year = int(start_date[:4]), int(end_date[:4])

    year_ranges = []
    y = start_year
    while y <= end_year:
        y2 = min(y + year_chunk - 1, end_year)
        year_ranges.append((f"{y}-01-01", f"{y2}-12-31"))
        y = y2 + 1

    all_parts = {i: [] for i in range(len(coords))}
    for chunk_start, chunk_end in year_ranges:
        print(f"Zeitraum {chunk_start[:4]}-{chunk_end[:4]}:")
        dfs = fetch_tmax_batch(client, coords, chunk_start, chunk_end, batch_size=batch_size, pause=pause)
        for i, df in enumerate(dfs):
            all_parts[i].append(df)
        time.sleep(pause)  # zusätzlicher Puffer zwischen Zeitblöcken

    return [pd.concat(all_parts[i], ignore_index=True).sort_values("date").reset_index(drop=True)
            for i in range(len(coords))]
    

def compute_doy_thresholds(ref_df, window=15, percentile=98):
    """Schwellenwert pro Kalendertag: 98. Perzentil aus ±15 Tagen der Referenzperiode."""
    doy = ref_df["doy"].to_numpy()
    tmax = ref_df["tmax"].to_numpy()
    thresholds = {}

    for d in range(1, 366):
        dist = np.abs(doy - d)
        dist = np.minimum(dist, 365 - dist)  # Jahreswechsel berücksichtigen
        thresholds[d] = np.percentile(tmax[dist <= window], percentile)

    return thresholds


def find_dwd_heatwaves(df, thresholds, min_days=3, fixed_threshold=28.0):
    """Hitzewelle = mind. 3 Tage in Folge über Klima-Schwelle UND über 28°C."""
    df = df.copy()
    df["doy"] = df["date"].dt.dayofyear.clip(upper=365)
    df["threshold"] = df["doy"].map(thresholds)
    df["is_hot"] = (df["tmax"] > df["threshold"]) & (df["tmax"] > fixed_threshold)

    heatwaves, start = [], None
    for i, row in df.iterrows():
        if row["is_hot"] and start is None:
            start = i
        elif not row["is_hot"] and start is not None:
            segment = df.loc[start:i - 1]
            if len(segment) >= min_days:
                heatwaves.append({
                    "start": segment["date"].iloc[0].date(),
                    "end": segment["date"].iloc[-1].date(),
                    "duration_days": len(segment),
                    "max_temp": round(segment["tmax"].max(), 1),
                    "avg_temp": round(segment["tmax"].mean(), 1)
                })
            start = None

    if start is not None:
        segment = df.loc[start:]
        if len(segment) >= min_days:
            heatwaves.append({
                "start": segment["date"].iloc[0].date(),
                "end": segment["date"].iloc[-1].date(),
                "duration_days": len(segment),
                "max_temp": round(segment["tmax"].max(), 1),
                "avg_temp": round(segment["tmax"].mean(), 1)
            })

    return heatwaves


def analyze_city_heatwaves_from_data(ref_df, analysis_df):
    """Verbindet Schwellenwert-Berechnung und Hitzewellen-Suche für eine Stadt."""
    ref_df = ref_df.copy()
    ref_df["doy"] = ref_df["date"].dt.dayofyear.clip(upper=365)
    thresholds = compute_doy_thresholds(ref_df)
    return find_dwd_heatwaves(analysis_df, thresholds)

# %% [markdown]
# Prüft mit 3 Städten und einem Monat, ob der neue Client korrekt antwortet, bevor der volle Lauf startet.

# %%
# Kurztest: prüfen ob Client + fetch_tmax_batch funktionieren (3 Städte, ein Monat)
coords = list(zip(cities_df["lat"], cities_df["lon"]))

test = fetch_tmax_batch(CLIENT, coords[:3], "2025-01-01", "2025-01-31")
[len(df) for df in test]   # sollte 3x ~31 ergeben
# Out:
#   Batch 1/1 ok (3 Städte)
# [31, 31, 31]

# %% [markdown]
# Kein manuelles Pickle-Caching mehr nötig — das übernimmt jetzt die CachedSession aus Zelle 2 transparent auf HTTP-Ebene. Bei einem 429 mitten im Lauf: Zelle einfach später erneut ausführen, bereits erfolgreiche Requests kommen sofort aus dem Cache.

# %%
#Fuer cache aufrufe DAS HIER NEHMEN!!
ref_dfs = fetch_tmax_range(CLIENT, coords, "1961-01-01", "1990-12-31", batch_size=15, year_chunk=10, pause=1)
# Out:
# Zeitraum 1961-1970:
#   Batch 1/4 ok (15 Städte)
#   Batch 2/4 ok (15 Städte)
#   Batch 3/4 ok (15 Städte)
#   Batch 4/4 ok (12 Städte)
# Zeitraum 1971-1980:
#   Batch 1/4 ok (15 Städte)
#   Batch 2/4 ok (15 Städte)
#   Batch 3/4 ok (15 Städte)
#   Batch 4/4 ok (12 Städte)
# Zeitraum 1981-1990:
#   Batch 1/4 ok (15 Städte)
#   Batch 2/4 ok (15 Städte)
#   Batch 3/4 ok (15 Städte)
#   Batch 4/4 ok (12 Städte)

# %%
#time.sleep(120) 
analysis_dfs = fetch_tmax_range(CLIENT, coords, "1980-01-01", "2025-12-31", batch_size=15, year_chunk=5, pause=1)
# Out:
# Zeitraum 1980-1984:
#   Batch 1/4 ok (15 Städte)
#   Batch 2/4 ok (15 Städte)
#   Batch 3/4 ok (15 Städte)
#   Batch 4/4 ok (12 Städte)
# Zeitraum 1985-1989:
#   Batch 1/4 ok (15 Städte)
#   Batch 2/4 ok (15 Städte)
#   Batch 3/4 ok (15 Städte)
#   Batch 4/4 ok (12 Städte)
# Zeitraum 1990-1994:
#   Batch 1/4 ok (15 Städte)
#   Batch 2/4 ok (15 Städte)
#   Batch 3/4 ok (15 Städte)
#   Batch 4/4 ok (12 Städte)
# Zeitraum 1995-1999:
#   Batch 1/4 ok (15 Städte)
#   Batch 2/4 ok (15 Städte)
#   Batch 3/4 ok (15 Städte)
#   Batch 4/4 ok (12 Städte)
# Zeitraum 2000-2004:
#   Batch 1/4 ok (15 Städte)
#   Batch 2/4 ok (15 Städte)
#   Batch 3/4 ok (15 Städte)
#   Batch 4/4 ok (12 Städte)
# Zeitraum 2005-2009:
#   Batch 1/4 ok (15 Städte)
#   Batch 2/4 ok (15 Städte)
#   Batch 3/4 ok (15 Städte)
#   Batch 4/4 ok (12 Städte)
# Zeitraum 2010-2014:
#   Batch 1/4 ok (15 Städte)
#   Batch 2/4 ok (15 Städte)
#   Batch 3/4 ok (15 Städte)
#   Batch 4/4 ok (12 Städte)
# Zeitraum 2015-2019:
#   Batch 1/4 ok (15 Städte)
#   Batch 2/4 ok (15 Städte)
#   Batch 3/4 ok (15 Städte)
#   Batch 4/4 ok (12 Städte)
# Zeitraum 2020-2024:
#   Batch 1/4 ok (15 Städte)
#   Batch 2/4 ok (15 Städte)
#   Batch 3/4 ok (15 Städte)
#   Batch 4/4 ok (12 Städte)
# Zeitraum 2025-2025:
#   Batch 1/4 ok (15 Städte)
#   Batch 2/4 ok (15 Städte)
#   Batch 3/4 ok (15 Städte)
#   Batch 4/4 ok (12 Städte)

# %%
exclude_idx = {5}  # Freie Hansestadt Bremen -- Bundesland, nicht die Stadt; ggf. Indizes aus Diagnose oben ergänzen

# %%
# Referenzperiode (1961-1990) und Analysejahr (2025) laden, dann Hitzewellen berechnen
results = []
failed_cities = []

for idx, row in cities_df.iterrows():
    if idx in exclude_idx:
        continue
    try:
        heatwaves = analyze_city_heatwaves_from_data(ref_dfs[idx], analysis_dfs[idx])
        for hw in heatwaves:
            results.append({"city": row["city"], "population": row["population"], **hw})
    except Exception as e:
        print(f"  Übersprungen wegen Fehler ({row['city']}): {e}")
        failed_cities.append(row["city"])

results_df = pd.DataFrame(results)
print(results_df)
print(f"\nFehlgeschlagen: {failed_cities}")
# Out:
#             city  population       start         end  duration_days  \
# 0         Berlin     3782202  1982-05-31  1982-06-04              5
# 1         Berlin     3782202  1992-06-01  1992-06-04              4
# 2         Berlin     3782202  1992-08-07  1992-08-09              3
# 3         Berlin     3782202  1994-07-21  1994-07-31             11
# 4         Berlin     3782202  1997-08-23  1997-08-25              3
# ...          ...         ...         ...         ...            ...
# 1565  Regensburg      151517  2022-08-02  2022-08-04              3
# 1566  Regensburg      151517  2023-08-18  2023-08-21              4
# 1567  Regensburg      151517  2024-08-28  2024-08-31              4
# 1568  Regensburg      151517  2025-06-28  2025-07-01              4
# 1569  Regensburg      151517  2025-08-12  2025-08-14              3
#
#        max_temp   avg_temp
# 0     32.000000  30.400000
# 1     28.799999  28.600000
# 2     37.700001  35.599998
# 3     36.700001  33.200001
# 4     31.100000  30.400000
# ...         ...        ...
# 1565  33.099998  32.500000
# 1566  31.600000  30.900000
# 1567  30.400000  29.600000
# 1568  34.000000  32.200001
# 1569  33.400002  32.700001
#
# [1570 rows x 7 columns]
#
# Fehlgeschlagen: []

# %%
starts = pd.to_datetime(results_df["start"])
print(f"Gefundene Hitzewellen gesamt: {len(results_df)}")
print(f"Zeitraum: {starts.dt.year.min()} bis {starts.dt.year.max()}")
# Out:
# Gefundene Hitzewellen gesamt: 1570
# Zeitraum: 1982 bis 2025

# %%
import os

os.makedirs("data/raw", exist_ok=True)
os.makedirs("data/processed", exist_ok=True)

raw_rows = []
for idx, row in cities_df.iterrows():
    if idx in exclude_idx:
        continue
    df = analysis_dfs[idx].copy()
    df["city"] = row["city"]
    raw_rows.append(df)
raw_df = pd.concat(raw_rows, ignore_index=True)
raw_df.to_parquet("data/raw/tmax_1980_2025.parquet", index=False)

results_df["year"] = pd.to_datetime(results_df["start"]).dt.year
results_df.to_csv("data/processed/heatwaves.csv", index=False)

# One-time export: save the reference period (1961-1990) too, so other
# notebooks can reuse it without ever touching the API again.
ref_rows = []
for idx, row in cities_df.iterrows():
    if idx in exclude_idx:
        continue
    df = ref_dfs[idx].copy()
    df["city"] = row["city"]
    ref_rows.append(df)
pd.concat(ref_rows, ignore_index=True).to_parquet("data/raw/tmax_1961_1990.parquet", index=False)
print("Reference period saved to data/raw/tmax_1961_1990.parquet")
# Out:
# Reference period saved to data/raw/tmax_1961_1990.parquet

# %%
all_years = pd.DataFrame({"year": range(1980, 2026)})
yearly = all_years.merge(
    results_df.groupby("year").agg(
        n_heatwaves=("city", "count"),
        avg_max_temp=("max_temp", "mean"),
        avg_avg_temp=("avg_temp", "mean"),
        avg_duration=("duration_days", "mean"),
    ).reset_index(),
    on="year", how="left"
)
yearly["n_heatwaves"] = yearly["n_heatwaves"].fillna(0).astype(int)
print(yearly)
# Out:
#     year  n_heatwaves  avg_max_temp  avg_avg_temp  avg_duration
# 0   1980            0           NaN           NaN           NaN
# 1   1981            0           NaN           NaN           NaN
# 2   1982           48     29.875000     29.264582      3.791667
# 3   1983           11     34.636364     33.281818      3.000000
# 4   1984            0           NaN           NaN           NaN
# 5   1985            0           NaN           NaN           NaN
# 6   1986            1     31.200001     30.400000      3.000000
# 7   1987            0           NaN           NaN           NaN
# 8   1988            0           NaN           NaN           NaN
# 9   1989            0           NaN           NaN           NaN
# 10  1990           27     34.085186     32.614815      3.111111
# 11  1991            8     28.625000     28.424999      3.000000
# 12  1992           29     33.937931     32.710342      3.068966
# 13  1993            0           NaN           NaN           NaN
# 14  1994           73     32.624660     31.310959      3.780822
# 15  1995           21     31.766666     31.095238      3.000000
# 16  1996           19     30.278946     29.242104      3.000000
# 17  1997            4     30.525000     29.725000      3.000000
# 18  1998           10     32.060001     31.070002      3.200000
# 19  1999           12     29.608332     29.074999      3.416667
# 20  2000           32     32.093750     31.062500      3.031250
# 21  2001            9     32.688889     30.933332      3.000000
# 22  2002            7     31.228573     30.142857      3.428571
# 23  2003           69     34.237679     32.259418      7.028986
# 24  2004            8     30.750000     29.950001      3.000000
# 25  2005            3     29.366667     29.000000      3.000000
# 26  2006           85     33.843529     32.301178      3.905882
# 27  2007            1     28.799999     28.500000      3.000000
# 28  2008            7     29.928572     29.428572      3.428571
# 29  2009            0           NaN           NaN           NaN
# 30  2010           57     33.678947     32.414036      4.368421
# 31  2011            9     31.333334     30.644444      3.777778
# 32  2012           33     34.342426     31.939394      3.303030
# 33  2013           22     32.481815     31.340910      3.227273
# 34  2014           28     32.178570     30.939285      3.642857
# 35  2015           81     34.927162     32.920990      4.172840
# 36  2016           99     31.594948     30.460608      4.030303
# 37  2017           36     33.147224     31.063890      3.666667
# 38  2018          136     33.355145     32.176472      3.816176
# 39  2019          159     34.383648     32.394966      4.150943
# 40  2020           82     33.007317     31.647562      5.256098
# 41  2021           52     32.690384     31.259615      3.788462
# 42  2022          109     33.238533     31.799084      3.559633
# 43  2023           69     30.491302     29.707247      4.855072
# 44  2024           21     31.985714     30.309525      4.809524
# 45  2025           93     34.995701     33.133331      3.397849

# %%
import matplotlib.pyplot as plt
import numpy as np

all_years_range = np.arange(1980, 2026)

def style_axis(ax, ylabel):
    ax.set_xlabel("Jahr")
    ax.set_ylabel(ylabel)
    ax.set_xticks(all_years_range)
    ax.set_xticklabels(all_years_range, rotation=90, fontsize=7)
    ax.grid(axis="x", alpha=0.3)
    ax.grid(axis="y", alpha=0.3)

plots = [
    ("n_heatwaves", "Anzahl Hitzewellen pro Jahr (alle 57 Städte)", "Anzahl Hitzewellen", "steelblue", "trend_frequency"),
    ("avg_max_temp", "Ø Spitzentemperatur pro Jahr", "Temperatur (°C)", "darkred", "trend_peak_temp"),
    ("avg_avg_temp", "Ø Durchschnittstemperatur pro Jahr", "Temperatur (°C)", "orange", "trend_avg_temp"),
    ("avg_duration", "Ø Dauer pro Hitzewelle", "Dauer (Tage)", "purple", "trend_duration"),
]

for col, title, ylabel, color, filename in plots:
    fig, ax = plt.subplots(figsize=(14, 7))
    ax.plot(yearly["year"], yearly[col], marker="o", color=color)
    ax.set_title(title)
    style_axis(ax, ylabel)
    plt.tight_layout()
    plt.savefig(f"data/processed/{filename}.png", dpi=400)
    plt.show()

# %%
def plot_with_gap_dashes(ax, x, y, color, marker="o"):
    x = x.to_numpy()
    y = y.to_numpy()

    # Marker fuer alle echten Punkte
    ax.plot(x, y, marker=marker, linestyle="none", color=color, zorder=2)

    # Segmente einzeln zeichnen: durchgezogen bei Δ=1 Jahr, gestrichelt bei groesserer Luecke
    for i in range(len(x) - 1):
        gap = x[i + 1] - x[i]
        style = "-" if gap == 1 else "--"
        ax.plot(x[i:i+2], y[i:i+2], linestyle=style, color=color, linewidth=1.5, zorder=1)


fig, axes = plt.subplots(2, 2, figsize=(18, 10))

axes[0,0].plot(yearly["year"], yearly["n_heatwaves"], marker="o")
axes[0,0].set_title("Anzahl Hitzewellen pro Jahr (alle 57 Städte)")
style_axis(axes[0,0], "Anzahl Hitzewellen")

for col, ax, color, title, ylabel in [
    ("avg_max_temp", axes[0,1], "darkred", "Ø Spitzentemperatur pro Jahr", "Temperatur (°C)"),
    ("avg_avg_temp", axes[1,0], "orange", "Ø Durchschnittstemperatur pro Jahr", "Temperatur (°C)"),
    ("avg_duration", axes[1,1], "purple", "Ø Dauer pro Hitzewelle", "Dauer (Tage)"),
]:
    valid = yearly.dropna(subset=[col])
    plot_with_gap_dashes(ax, valid["year"], valid[col], color)
    ax.set_title(title)
    style_axis(ax, ylabel)

plt.tight_layout()
plt.savefig("data/processed/trend_overview_gestrichelt.png", dpi=150)
plt.show()

# %%
from scipy import stats

for col, label in [("n_heatwaves", "Häufigkeit"), ("avg_max_temp", "Spitzentemp."),
                    ("avg_avg_temp", "Durchschnittstemp."), ("avg_duration", "Dauer")]:
    valid = yearly.dropna(subset=[col])
    slope, intercept, r, p, se = stats.linregress(valid["year"], valid[col])
    signif = "signifikant" if p < 0.05 else "nicht signifikant"
    print(f"{label}: {slope:+.3f}/Jahr, p={p:.4f} ({signif}), R²={r**2:.3f}, n={len(valid)}")
# Out:
# Häufigkeit: +1.824/Jahr, p=0.0000 (signifikant), R²=0.373, n=46
# Spitzentemp.: +0.039/Jahr, p=0.1100 (nicht signifikant), R²=0.071, n=37
# Durchschnittstemp.: +0.021/Jahr, p=0.2532 (nicht signifikant), R²=0.037, n=37
# Dauer: +0.028/Jahr, p=0.0107 (signifikant), R²=0.172, n=37

# %%
yearly_no_overlap = yearly[yearly["year"] >= 1991]

from scipy import stats
for col, label in [("n_heatwaves", "Häufigkeit"), ("avg_max_temp", "Spitzentemp."),
                    ("avg_avg_temp", "Durchschnittstemp."), ("avg_duration", "Dauer")]:
    valid = yearly_no_overlap.dropna(subset=[col])
    slope, intercept, r, p, se = stats.linregress(valid["year"], valid[col])
    signif = "signifikant" if p < 0.05 else "nicht signifikant"
    print(f"{label} (nur 1991–2025, keine Überlappung): {slope:+.3f}/Jahr, p={p:.4f} ({signif}), R²={r**2:.3f}, n={len(valid)}")
# Out:
# Häufigkeit (nur 1991–2025, keine Überlappung): +2.294/Jahr, p=0.0005 (signifikant), R²=0.313, n=35
# Spitzentemp. (nur 1991–2025, keine Überlappung): +0.067/Jahr, p=0.0245 (signifikant), R²=0.153, n=33
# Durchschnittstemp. (nur 1991–2025, keine Überlappung): +0.043/Jahr, p=0.0527 (nicht signifikant), R²=0.116, n=33
# Dauer (nur 1991–2025, keine Überlappung): +0.033/Jahr, p=0.0206 (signifikant), R²=0.161, n=33

# %% [markdown]
# Fazit: Über alle 57 Großstädte hinweg hat die Häufigkeit von Hitzewellen zwischen 1980 und 2025 signifikant zugenommen (+1,8/Jahr, p<0,001), ebenso die durchschnittliche Dauer je Hitzewelle (+0,03 Tage/Jahr, p=0,011). Die Intensität ist der schwächere Trend: Die Spitzentemperatur steigt nur im überlappungsfreien Zeitfenster (1991–2025) signifikant (+0,07 °C/Jahr, p=0,025), die Durchschnittstemperatur je Hitzewelle bleibt statistisch nicht eindeutig nachweisbar. Insgesamt: Hitzewellen werden häufiger und länger, aber nicht dramatisch heißer pro Ereignis.

# %%
def build_city_yearly(city):
    city_df = results_df[results_df["city"] == city]
    yearly = all_years.merge(
        city_df.groupby("year").agg(
            n_heatwaves=("city", "count"),
            avg_max_temp=("max_temp", "mean"),
            avg_avg_temp=("avg_temp", "mean"),
            avg_duration=("duration_days", "mean"),
        ).reset_index(),
        on="year", how="left"
    )
    yearly["n_heatwaves"] = yearly["n_heatwaves"].fillna(0).astype(int)
    yearly["city"] = city
    return yearly

city_yearly_all = pd.concat([build_city_yearly(c) for c in cities_of_interest], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 16
#      12     yearly["n_heatwaves"] = yearly["n_heatwaves"].fillna(0).astype(int)
#      13     yearly["city"] = city
#      14     return yearly
#      15
# ---> 16 city_yearly_all = pd.concat([build_city_yearly(c) for c in cities_of_interest], ignore_index=True)
#
# NameError: name 'cities_of_interest' is not defined

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 4.8))

def style_axis_poster(ax, ylabel, title):
    ax.set_title(title, fontsize=15, fontweight="bold", pad=10)
    ax.set_xlabel("Year", fontsize=12)
    ax.set_ylabel(ylabel, fontsize=12)
    tick_years = [y for y in all_years_range if y % 5 == 0]
    ax.set_xticks(tick_years)
    ax.set_xticklabels(tick_years, rotation=0, fontsize=11)
    ax.tick_params(axis="y", labelsize=11)
    ax.grid(axis="both", alpha=0.3)
    for spine in ax.spines.values():
        spine.set_linewidth(0.8)

axes[0].plot(yearly["year"], yearly["n_heatwaves"], marker="o", color="#1f77b4", linewidth=1.8)
style_axis_poster(axes[0], "Number of heatwaves", "Number of heatwaves per year")

valid = yearly.dropna(subset=["avg_duration"])
plot_with_gap_dashes(axes[1], valid["year"], valid["avg_duration"], "purple")
style_axis_poster(axes[1], "Duration (Days)", "Ø Duration per heatwave")

plt.tight_layout()
plt.savefig("data/processed/poster_frequency_duration.png", dpi=300, bbox_inches="tight", facecolor="white")
plt.show()

# %%
# Poster chart: replaces the two line plots with decade-binned bars
def decade_bin(year):
    if year < 1990: return "1980–89"
    elif year < 2000: return "1990–99"
    elif year < 2010: return "2000–09"
    elif year < 2020: return "2010–19"
    else: return "2020–25"

yearly["decade"] = yearly["year"].apply(decade_bin)
decade_order = ["1980–89", "1990–99", "2000–09", "2010–19", "2020–25"]

decade_stats = yearly.groupby("decade").agg(
    freq_mean=("n_heatwaves", "mean"), freq_std=("n_heatwaves", "std"),
    dur_mean=("avg_duration", "mean"), dur_std=("avg_duration", "std"),
).reindex(decade_order)

fig, axes = plt.subplots(1, 2, figsize=(10, 4.5))

axes[0].bar(decade_order, decade_stats["freq_mean"], yerr=decade_stats["freq_std"],
            color="steelblue", capsize=4)
axes[0].set_title("Number of heatwaves per year")  # <- match the box's original title style
axes[0].set_ylabel("Heatwaves/year (avg.)")
axes[0].tick_params(axis="x", rotation=30)
axes[0].grid(axis="y", alpha=0.3)

axes[1].bar(decade_order, decade_stats["dur_mean"], yerr=decade_stats["dur_std"],
            color="purple", capsize=4)
axes[1].set_title("Ø Duration per heatwave")
axes[1].set_ylabel("Duration (days, avg.)")
axes[1].tick_params(axis="x", rotation=30)
axes[1].grid(axis="y", alpha=0.3)

plt.tight_layout()
plt.savefig("data/processed/poster_decade_bars.png", dpi=400)
plt.savefig("data/processed/poster_decade_bars.svg")  # Vektorgrafik -- für PowerPoint, bleibt bei jeder Größe scharf
plt.show()
